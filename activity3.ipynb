# %%
# import required packages
import pandas as pd
import requests
import hashlib
import json
import string

# %%
# function to create characters dataframe by making API call
def create_character_df (input_apikey, input_hash, nameStartWith):
    ts = 1
    address = 'http://gateway.marvel.com/v1/public/characters'
    df = pd.DataFrame()

    #looping to get all characters starting with certain character, when there are more than 100 suitable characters - using offset
    for i in range(0,3):
        parameters = {
            'apikey':input_apikey,
            'ts':ts,
            'hash':input_hash,
            'limit':100,
            'nameStartsWith':nameStartWith,
            'offset':100*i
        }
        response = requests.get(address, params=parameters)
        response.raise_for_status()                             # raise exception if http error
        results = response.json()
        df_new = pd.json_normalize(results['data']['results'])
        df = pd.concat([df, df_new], ignore_index=True)
    character_df = df[['id','name','events.available','series.available','stories.available','comics.available']]
    return(character_df)

# %%
public_key = '486e33cb6586570842beb1fdc21db6c2'
private_key = '4893102e65894f0350a76693dff1b2bc9418a52a'
ts = 1
hash = hashlib.md5((str(ts)+private_key+public_key).encode()).hexdigest()

# %%
# checking our function while passing all required parameters
char_df = create_character_df(input_apikey=public_key, input_hash=hash, nameStartWith='S')
char_df
# Out:
#           id                            name  events.available  \
# 0    1009552                    S.H.I.E.L.D.                 1
# 1    1009553                           Sabra                 0
# 2    1009554                      Sabretooth                 8
# 3    1010969  Sabretooth (Age of Apocalypse)                 1
# 4    1010970         Sabretooth (House of M)                 1
# ..       ...                             ...               ...
# 197  1017852     Sword Master (Sword Master)                 0
# 198  1009641                       Swordsman                 4
# 199  1010982    Swordsman (Jacques Duquesne)                 1
# 200  1009642                             Sym                 0
# 201  1009643                           Synch                 1
#
#      series.available  stories.available  comics.available
# 0                  72                196               165
# 1                  13                 21                21
# 2                 113                326               309
# 3                   7                 21                21
# 4                   1                  1                 1
# ..                ...                ...               ...
# 197                 7                 25                25
# 198                25                 56                60
# 199                 2                  4                 4
# 200                 1                  3                 2
# 201                12                 18                18
#
# [202 rows x 6 columns]

# %%
# checking our function while passing one missing parameter - to check the https error 
char_df = create_character_df(input_apikey='', input_hash=hash, nameStartWith='S')
char_df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Urvi\technical_training\Module 5\activity3_v1.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> char_df = create_character_df(input_apikey='', input_hash=hash, nameStartWith='S')
#       <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> char_df
#
# c:\Urvi\technical_training\Module 5\activity3_v1.ipynb Cell 5 in create_character_df(input_apikey, input_hash, nameStartWith)
#       <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> parameters = {
#      <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     'apikey':public_key,
#      <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>     'ts':ts,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>     'offset':100*i
#      <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> }
#      <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a> response = requests.get(address, params=parameters)
# ---> <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> response.raise_for_status()
#      <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> results = response.json()
#      <a href='vscode-notebook-cell:/c%3A/Urvi/technical_training/Module%205/activity3_v1.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a> df_new = pd.json_normalize(results['data']['results'])
#
# File c:\ProgramData\Anaconda3\lib\site-packages\requests\models.py:960, in Response.raise_for_status(self)
#     957     http_error_msg = u'%s Server Error: %s for url: %s' % (self.status_code, reason, self.url)
#     959 if http_error_msg:
# --> 960     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: http://gateway.marvel.com/v1/public/characters?apikey=&ts=1&hash=d5e696cab9a4f6c90b24080590561993&limit=100&nameStartsWith=S&offset=0
